# %% [markdown]
# <a href="https://colab.research.google.com/github/mmotztulane/CSCapstone/blob/main/PublicRecords_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# %%capture
# !pip install bertopic
import pandas as pd
import spacy
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

# %%
# requests data - convert to list of strings
requests = pd.read_csv('Public_Records_Requests.csv')
requests = requests['Request Text'].tolist()

# %%
# training
topic_model_1 = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model_1.fit_transform(requests)
# Out:
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]

# %%
# save model 1
topic_model_1.save("PublicRecords_Model1")

# %%
# most frequent topics: -1 indicates outliers, ignore
freq = topic_model_1.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                  Name
# 0      -1   2530                      -1_the_and_of_in
# 1       0    223       0_fire_report_occurred_incident
# 2       1    144       1_camera_footage_video_accident
# 3       2    135       2_fire_incident_report_occurred
# 4       3    132  3_rfp_proposals_selection_evaluation
# 5       4    104             4_public_records_fees_act
# 6       5    104                  5_paid_taxes_nola_st
# 7       6    100          6_street_permits_orleans_new
# 8       7     93        7_incident_initial_report_view
# 9       8     93                 8_paid_taxes_years_la
# 10      9     82        9_emails_january_between_email
# 11     10     78       10_hearing_case_audio_recording
# 12     11     75          11_permits_permit_llc_issued
# 13     12     73           12_death_ostroff_caitlin_im
# 14     13     72          13_code_violations_open_fire
# 15     14     70               14_911_call_audio_calls
# 16     15     66        15_bid_unit_tabulations_prices
# 17     16     66       16_body_footage_camera_accident
# 18     17     65          17_nofd_fire_incident_report
# 19     18     60                18_bill_bills_tax_paid

# %%
topic_model_1.get_topic(0) # get the most frequent topic
# Out:
# [('fire', 0.05267922523855218),
#  ('report', 0.03489122195061917),
#  ('occurred', 0.03273741016577411),
#  ('incident', 0.025259593276499192),
#  ('la', 0.02479762762000258),
#  ('involving', 0.02093564846224196),
#  ('new', 0.018817773365469956),
#  ('orleans', 0.01856295081160376),
#  ('on', 0.017813844971275566),
#  ('at', 0.01724144049364158)]

# %%
topic_model_1.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('camera', 0.03233983545989223),
#  ('footage', 0.03190395171780871),
#  ('video', 0.03158366868124489),
#  ('accident', 0.03074310280447741),
#  ('intersection', 0.030413903174532117),
#  ('pm', 0.02656250932480622),
#  ('traffic', 0.017989825800340278),
#  ('cameras', 0.015957888315200414),
#  ('at', 0.015665788564913737),
#  ('on', 0.015453408727017172)]

# %%
# size of each circle = frequency of topic
interactive_map = topic_model_1.visualize_topics(); interactive_map
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a5104f2c-6aab-493b-8f4d-9c8ae8be89b5" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5104f2c-6aab-493b-8f4d-9c8ae8be89b5")) {                    Plotly.newPlot(                        "a5104f2c-6aab-493b-8f4d-9c8ae8be89b5",                        [{"customdata":[[0,"fire | report | occurred | incident | la",223],[1,"camera | footage | video | accident | intersection",144],[2,"fire | incident | report | occurred | on",135],[3,"rfp | proposals | selection | evaluation | proposal",132],[4,"public | records | fees | act | request",104],[5,"paid | taxes | nola | st | payment",104],[6,"street | permits | orleans | new | la",100],[7,"incident | initial | report | view | reports",93],[8,"paid | taxes | years | la | bill",93],[9,"emails | january | between | email | 2018",82],[10,"hearing | case | audio | recording | 2018",78],[11,"permits | permit | llc | issued | applications",75],[12,"death | ostroff | caitlin | im | homicide",73],[13,"code | violations | open | fire | parcel",72],[14,"911 | call | audio | calls | seconds",70],[15,"bid | unit | tabulations | prices | group",66],[16,"body | footage | camera | accident | item",66],[17,"nofd | fire | incident | report | vehicle",65],[18,"bill | bills | tax | paid | my",60],[19,"send | immovable | post | pre | entity",60],[20,"monuments | monument | removal | beauregard | lee",58],[21,"sale | adjudicated | mail | tax | cin",58],[22,"fire | report | copy | incident | occurred",55],[23,"sale | tax | notice | giving | redeem",55],[24,"contract | contracts | between | services | city",54],[25,"bid | pw | project | construction | restoration",50],[26,"traffic | signal | intersection | sequence | signals",49],[27,"demolition | demolished | she | structure | danger",46],[28,"police | initial | item | inspect | emilynbsp",46],[29,"valorem | ad | unpaid | sale | posttax",45],[30,"salary | position | employees | salaries | unclassified",45],[31,"retirement | fund | millage | budget | fiscal",45],[32,"zoning | variances | copies | occupancy | special",44],[33,"sale | notices | sent | tax | salestax",43],[34,"officers | nopd | 2022 | officer | termination",43],[35,"view | report | may | ursulines | initial",43],[36,"loss | fire | report | date | serve",42],[37,"judgment | judgments | settlement | list | settlements",40],[38,"tcsp | camera | traffic | cameras | tickets",40],[39,"parking | tow | bike | western | share",40],[40,"pib | letter | investigative | supervisor | discipline",39],[41,"ebi | historical | esa | current | sewer",39],[42,"delinquencies | sales | owners | tax | tend",38],[43,"spills | hazardous | releases | storage | street",38],[44,"firearm | stolen | firearms | data | lost",37],[45,"occupational | license | licenses | business | alcoholic",37],[46,"violations | code | nicole | thompson | open",36],[47,"checks | payee | uncashed | unclaimed | check",35],[48,"onsite | inspection | initial | incident | report",35],[49,"nopd | initial | police | item | emilynbsp",35],[50,"building | violations | zoning | are | code",34],[51,"cpnc | cab | taxi | numbers | insurance",34],[52,"dog | spca | bite | animals | animal",34],[53,"mayor | landrieus | aug | mitch | administration",34],[54,"ordinance | docket | bza | adjustments | zoning",33],[55,"entergy | staff | agents | councilmember | communications",33],[56,"cea | request | making | public | records",32],[57,"112013 | annunciation | tonbspnbsp | since | present",32],[58,"nbspnbspnbsp | iserv | driver | manila | agencynew",32],[59,"environmental | phase | conducting | site | incidents",32],[60,"fire | report | copy | requesting | upcoming",31],[61,"signs | sign | speed | limit | school",29],[62,"list | properties | delinquent | auction | yet",29], ...

# %%
# Set labels for top 10 topics
topic_model_1.set_topic_labels({0: "Fire Incident", 1: "Traffic Camera Footage",
                                2: "Fire Incident", 3: "RFP", 4: "Public Records Requests",
                                5: "Tax Payment", 6: "Street Permits", 7: "Incident Reports",
                                8: "Taxes", 9: "Emails"})

# Display model 1 bar chart
topic_model_1.visualize_barchart(top_n_topics=10, title='Model 1: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f1abe984-669c-4ec5-8b73-ba3756cc26e6" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1abe984-669c-4ec5-8b73-ba3756cc26e6")) {                    Plotly.newPlot(                        "f1abe984-669c-4ec5-8b73-ba3756cc26e6",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.02479762762000258,0.025259593276499192,0.03273741016577411,0.03489122195061917,0.05267922523855218],"y":["la  ","incident  ","occurred  ","report  ","fire  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.030413903174532117,0.03074310280447741,0.03158366868124489,0.03190395171780871,0.03233983545989223],"y":["intersection  ","accident  ","video  ","footage  ","camera  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.020669474450986308,0.02281475825719219,0.05309938780248246,0.053128160744363884,0.07749107496707],"y":["on  ","occurred  ","report  ","incident  ","fire  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.02146600879747555,0.022029268666241927,0.022821365813158634,0.030761435259659273,0.054961234005159745],"y":["proposal  ","evaluation  ","selection  ","proposals  ","rfp  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.009619808829002484,0.009660220146629296,0.01040392062167346,0.010987876236210507,0.014232600749637609],"y":["request  ","act  ","fees  ","records  ","public  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.029127394038765162,0.02942403219010012,0.036764906864309076,0.0502273571329086,0.06364836405034127],"y":["payment  ","st  ","nola  ","taxes  ","paid  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.013419668526155008,0.014517542029623692,0.014779132486297548,0.01788189790444453,0.020005994103993948],"y":["la  ","new  ","orleans  ","permits  ","street  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.023469124399333408,0.03928720661110623,0.04424948983540205,0.06738619642618424,0.09465361971697014],"y":["reports  ","view  ","report  ","initial  ","incident  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.020659585798165365,0.021791360560341106,0.023541091920825374,0.0272785316072971,0.030991547133297544],"y":["bill  ","la  ","years  ","taxes  ","paid  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.019097544437270547,0.019287980240412634,0.020801490130196557,0.025396080382457605,0.03522243224707284],"y":["2018  ","email  ","between  ","january  ","emails  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colors ...

# %%
# change ngram_range, let each entity in a topic be up to 3 words
vectorizer_model = CountVectorizer(ngram_range=(1, 3))

# update model 1
topic_model_1.update_topics(requests, vectorizer_model=vectorizer_model)

# %%
# get most frequent topics: ngram_range = (1,3)
freq = topic_model_1.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                               Name
# 0      -1   2374                                   -1_the_and_of_to
# 1       0    364                              0_paid_tax_bill_taxes
# 2       1    223                 1_fire_report_the fire_fire report
# 3       2    143                    2_rfp_proposals_rfp no_proposal
# 4       3    134                 3_fire_report_incident_fire report
# 5       4    132             4_camera_footage_accident_intersection
# 6       5    110            5_public_records_request_public records
# 7       6     96            6_bid_group_tabulations_bid tabulations
# 8       7     89               7_contract_the city_the city of_city
# 9       8     87  8_incident_initial incident_incident report_in...
# 10      9     78                           9_911_call_the 911_calls
# 11     10     76                  10_sale_tax sale_tax_tax sale for
# 12     11     74                  11_permits_permit_all permits_llc
# 13     12     73                  12_hearing_the hearing_case_audio
# 14     13     72                      13_im_death_homicide_reporter
# 15     14     72      14_emails_nbsp nbsp nbsp_all emails_nbsp nbsp
# 16     15     71              15_bid_construction_submitted_the bid
# 17     16     71  16_fire code_fire code violations_code violati...
# 18     17     69  17_street_street new orleans_street new_new or...
# 19     18     68                    18_body_footage_camera_accident

# %%
# train a new model with modified topic sizes (min topic size = 5)
topic_model_2 = BERTopic(language="english", min_topic_size=5, calculate_probabilities=True, verbose=True)
topics, probs = topic_model_2.fit_transform(requests)
# Out:
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]

# %%
# save model 2
topic_model_2.save("PublicRecords_Model2")

# %%
# most frequent topics: model 2
freq = topic_model_2.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                      Name
# 0      -1   2122                          -1_the_and_in_of
# 1       0    365                     0_paid_bill_taxes_tax
# 2       1    243           1_fire_report_occurred_incident
# 3       2    132     2_video_footage_intersection_accident
# 4       3     79            3_rfp_proposals_sheets_scoring
# 5       4     77            4_incident_initial_view_report
# 6       5     74           5_permit_permits_seasons_issued
# 7       6     74             6_code_violations_open_parcel
# 8       7     69             7_bid_unit_prices_tabulations
# 9       8     68                 8_body_footage_camera_cam
# 10      9     62               9_fire_report_copy_incident
# 11     10     61                10_immovable_send_post_pre
# 12     11     59    11_budget_millage_fiscal_disbursements
# 13     12     58  12_monuments_monument_removal_beauregard
# 14     13     56                 13_911_call_audio_seconds
# 15     14     55     14_fire_incident_report_approximately
# 16     15     53            15_ord_resolution_view_initial
# 17     16     53            16_homicide_death_crime_murder
# 18     17     52                17_street_la_located_canal
# 19     18     51     18_employees_employee_overtime_salary

# %%
topic_model_2.get_topic(0) # get the most frequent topic
# Out:
# [('paid', 0.030763668590070976),
#  ('bill', 0.022534097061466675),
#  ('taxes', 0.021453433857983782),
#  ('tax', 0.01726269520375312),
#  ('bills', 0.014618764186750375),
#  ('payment', 0.013607243854968174),
#  ('years', 0.013133040618896929),
#  ('need', 0.011279474878138566),
#  ('amount', 0.01105217765898051),
#  ('property', 0.01071072975638051)]

# %%
topic_model_2.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('fire', 0.03495184621558374),
#  ('report', 0.023251193681501966),
#  ('occurred', 0.022447373691165347),
#  ('incident', 0.018760099343314),
#  ('la', 0.015005217922794222),
#  ('involving', 0.014626335187983272),
#  ('new', 0.010739276696985394),
#  ('on', 0.010698407010312922),
#  ('orleans', 0.010648460715898724),
#  ('at', 0.010626758741238479)]

# %%
# Set labels for top 10 topics
topic_model_2.set_topic_labels({0: "Tax Payments", 1: "Fire Incident",
                                2: "Traffic Camera Footage", 3: "RFP", 4: "Incident Reports",
                                5: "Permit Applications", 6: "Code Violations", 7: "Pricing",
                                8: "Body Camera Footage", 9: "Fire Incident"})

# Display model 2 bar chart
topic_model_2.visualize_barchart(top_n_topics=10, title='Model 2: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="886ad23b-873e-4fe6-8a8a-d53099f2223a" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("886ad23b-873e-4fe6-8a8a-d53099f2223a")) {                    Plotly.newPlot(                        "886ad23b-873e-4fe6-8a8a-d53099f2223a",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.014618764186750375,0.01726269520375312,0.021453433857983782,0.022534097061466675,0.030763668590070976],"y":["bills  ","tax  ","taxes  ","bill  ","paid  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.015005217922794222,0.018760099343314,0.022447373691165347,0.023251193681501966,0.03495184621558374],"y":["la  ","incident  ","occurred  ","report  ","fire  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.024667236541970727,0.024886108349147704,0.025211326732346464,0.0253433572124383,0.02623340754581997],"y":["camera  ","accident  ","intersection  ","footage  ","video  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.023967742444525375,0.025484822162779273,0.027588874949775112,0.029056056351894642,0.07075668312015712],"y":["design  ","scoring  ","sheets  ","proposals  ","rfp  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.028254454468820734,0.0398713660517614,0.04488078695734207,0.07747022293933575,0.08482926537918688],"y":["item  ","report  ","view  ","initial  ","incident  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.014391804157429298,0.014505719110548466,0.017821843514232827,0.03363235813677758,0.03625741875955924],"y":["applications  ","issued  ","seasons  ","permits  ","permit  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0234662479792497,0.02386612647451665,0.03167873659194144,0.03253919613225479,0.034789119930775526],"y":["openunresolved  ","parcel  ","open  ","violations  ","code  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.06037886303188016,0.06886927492454022,0.07123671950257741,0.07519424836514871,0.08636930836523916],"y":["group  ","tabulations  ","prices  ","unit  ","bid  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.029735652546534243,0.03012008005328351,0.03394720870086044,0.04099295791180877,0.054757026384780264],"y":["accident  ","cam  ","camera  ","footage  ","body  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01497556475051458,0.015411040168579518,0.016291128228978522,0.019547423100744823,0.028852847990383863],"y":["occurred  ","incident  ","copy  ","report  ","fire  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0 ...

# %%
# train a new model with modified topic sizes (topic size = 5)
topic_model_3 = BERTopic(language="english", top_n_words=5, min_topic_size=5,
                         calculate_probabilities=True, verbose=True)
topics, probs = topic_model_3.fit_transform(requests)
# Out:
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]

# %%
# save model 3
topic_model_3.save("PublicRecords_Model3")

# %%
# most frequent topics: model 3
freq = topic_model_3.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                  Name
# 0      -1   2424                     -1_the_and_in_all
# 1       0     92               0_paid_taxes_years_bill
# 2       1     86    1_contract_contracts_services_city
# 3       2     83  2_permit_permits_applications_issued
# 4       3     81             3_body_footage_camera_cam
# 5       4     78  4_accident_video_intersection_camera
# 6       5     78         5_street_4412a_dating_permits
# 7       6     76        6_incident_initial_view_report
# 8       7     76        7_emails_january_2018_received
# 9       8     75                  8_public_fees_act_me
# 10      9     74                 9_bill_bills_paid_tax
# 11     10     69        10_code_violations_open_parcel
# 12     11     61            11_send_immovable_post_pre
# 13     12     56           12_911_audio_call_calltaker
# 14     13     55         13_view_initial_ursulines_may
# 15     14     54         14_bid_tabulations_group_unit
# 16     15     53      15_fire_report_occurred_incident
# 17     16     52              16_signs_sign_speed_lane
# 18     17     50       17_rfp_design_proposals_scoring
# 19     18     50           18_bid_pw_project_submitted

# %%
topic_model_3.get_topic(0) # get the most frequent topic
# Out:
# [('paid', 0.023392599683124887),
#  ('taxes', 0.018728375030529702),
#  ('years', 0.018574413885267912),
#  ('bill', 0.015169417880669438),
#  ('la', 0.014078575994031483)]

# %%
topic_model_3.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('contract', 0.02239770790045691),
#  ('contracts', 0.018548210489361925),
#  ('services', 0.017404181860354244),
#  ('city', 0.013677655011864817),
#  ('agreements', 0.013673633835138364)]

# %%
# Set labels for top 10 topics
topic_model_3.set_topic_labels({0: "Tax Payment", 1: "Contracts",
                                2: "Permit Applications", 3: "Body Camera Footage", 4: "Traffic Camera Footage",
                                5: "Permits", 6: "Incident Reports", 7: "Emails",
                                8: "Public Records", 9: "Tax Bills"})

# Display model 3 bar chart
topic_model_3.visualize_barchart(top_n_topics=10, title='Model 3: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4d42bb4b-34ba-4cd3-98b8-ac30648829b3" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d42bb4b-34ba-4cd3-98b8-ac30648829b3")) {                    Plotly.newPlot(                        "4d42bb4b-34ba-4cd3-98b8-ac30648829b3",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.014078575994031483,0.015169417880669438,0.018574413885267912,0.018728375030529702,0.023392599683124887],"y":["la  ","bill  ","years  ","taxes  ","paid  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.013673633835138364,0.013677655011864817,0.017404181860354244,0.018548210489361925,0.02239770790045691],"y":["agreements  ","city  ","services  ","contracts  ","contract  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012906401082331645,0.01308799152452739,0.01427483554556496,0.029566309224182137,0.034688232935404996],"y":["seasons  ","issued  ","applications  ","permits  ","permit  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.027754911816352326,0.029114650632945858,0.029265795174780194,0.03748053221560624,0.0463344482256426],"y":["accident  ","cam  ","camera  ","footage  ","body  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.023399418616477985,0.025588564563998644,0.026886741228913137,0.02808170750575372,0.02986251154416812],"y":["footage  ","camera  ","intersection  ","video  ","accident  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.009827837467011795,0.009987982407474979,0.010172654224337201,0.010773852193228383,0.012556233633409476],"y":["situated  ","permits  ","dating  ","4412a  ","street  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.025179166578868723,0.03746134306362381,0.044797590579957844,0.07259805192063475,0.08012468757079273],"y":["item  ","report  ","view  ","initial  ","incident  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.014648624943228526,0.014837927168910654,0.01642811139551734,0.019645362579785837,0.028274473683915797],"y":["between  ","received  ","2018  ","january  ","emails  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.0074552940559443085,0.0075265098592121275,0.007660390957306635,0.009088459366434744,0.009913592480987918],"y":["records  ","me  ","act  ","fees  ","public  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01731647677326496,0.02497076275552524,0.02580241477310561,0.03896225757370114,0.04171873409533207],"y":["my  ","tax  ","paid  ","bills  ","bill  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth": ...

# %%
# train new model, add diversity
topic_model_4 = BERTopic(language="english", calculate_probabilities=True, diversity=0.5, verbose=True)
topics, probs = topic_model_4.fit_transform(requests)
# Out:
# Batches:   0%|          | 0/242 [00:00<?, ?it/s]

# %%
# save model 4
topic_model_4.save("PublicRecords_Model4")

# %%
# most frequent topics: model 4
freq = topic_model_4.get_topic_info(); freq.head(20)
# Out:
#     Topic  Count                                    Name
# 0      -1   2320                   -1_all_records_or_new
# 1       0    350                   0_taxes_bills_st_nola
# 2       1    223              1_fire_orleans_happened_st
# 3       2    150   2_accident_intersection_traffic_crime
# 4       3    136    3_rfp_proposals_evaluation_submitted
# 5       4    135         4_public_records_fees_louisiana
# 6       5    123    5_hearing_rental_nicholls_recordings
# 7       6    115               6_fire_incident_2431_2020
# 8       7    110         7_group_tabulations_de_proposal
# 9       8    100      8_contracts_donation_deepwater_oil
# 10      9     92           9_incident_reports_yall_marta
# 11     10     88         10_sale_tax_adjudicated_notices
# 12     11     86     11_tennessee_street_orleans_permits
# 13     12     80    12_homicide_ostroff_caitlin_reporter
# 14     13     78           13_claims_utility_atampt_pole
# 15     14     76  14_permits_applications_issued_seasons
# 16     15     74      15_open_fire_parcel_openunresolved
# 17     16     73            16_footage_accident_cam_dash
# 18     17     72               17_911_calls_seconds_ring
# 19     18     68         18_emails_january_received_nbsp

# %%
topic_model_4.get_topic(0) # get the most frequent topic
# Out:
# [('taxes', 0.02530271397460279),
#  ('bills', 0.015073727022006201),
#  ('st', 0.010985627874413149),
#  ('nola', 0.010229897459317771),
#  ('andor', 0.010098585806939566),
#  ('estate', 0.008436083284670768),
#  ('mail', 0.008332047192687285),
#  ('presale', 0.008297518451924642),
#  ('payments', 0.008249751830665961),
#  ('notices', 0.008010579230723259)]

# %%
topic_model_4.get_topic(1) # get the 2nd most frequent topic
# Out:
# [('fire', 0.05161375796259105),
#  ('orleans', 0.01807454606534836),
#  ('happened', 0.010803363303864126),
#  ('st', 0.01030270774100855),
#  ('need', 0.008678603942663536),
#  ('avenue', 0.00765552346236769),
#  ('department', 0.007624992426648681),
#  ('investigation', 0.007187351008425922),
#  ('june', 0.006314481830658009),
#  ('70119', 0.006110321162769096)]

# %%
# Set labels for top 10 topics
topic_model_4.set_topic_labels({0: "Tax Bills", 1: "Fire Incident",
                                2: "Crime, Traffic Cameras", 3: "RFP", 4: "Public Records",
                                5: "City Court", 6: "Fire Incident", 7: "Proposals",
                                8: "Donations", 9: "Incident Reports"})

# Display model 4 bar chart
topic_model_4.visualize_barchart(top_n_topics=10, title='Model 4: Topic Word Scores',
                                 custom_labels=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4a1dccae-483d-40bd-8e29-9a708d33dcbb" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a1dccae-483d-40bd-8e29-9a708d33dcbb")) {                    Plotly.newPlot(                        "4a1dccae-483d-40bd-8e29-9a708d33dcbb",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.010098585806939566,0.010229897459317771,0.010985627874413149,0.015073727022006201,0.02530271397460279],"y":["andor  ","nola  ","st  ","bills  ","taxes  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.008678603942663536,0.01030270774100855,0.010803363303864126,0.01807454606534836,0.05161375796259105],"y":["need  ","st  ","happened  ","orleans  ","fire  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01474678556778971,0.015290363305563655,0.017605813323753196,0.029612738990723437,0.030640800591378973],"y":["cameras  ","crime  ","traffic  ","intersection  ","accident  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.01304559082845989,0.016837655774730696,0.022389231420856765,0.03049300349122278,0.056795274254341374],"y":["design  ","submitted  ","evaluation  ","proposals  ","rfp  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.006657865110802259,0.007491996937627266,0.008616096068000479,0.009692194392618158,0.0130273586663014],"y":["441  ","louisiana  ","fees  ","records  ","public  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.0104758438633711,0.011016168766568413,0.011798777174039349,0.01380344697976834,0.06343966771011904],"y":["held  ","recordings  ","nicholls  ","rental  ","hearing  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.019544736973707663,0.020010790880243844,0.022244758826944804,0.05531845595088649,0.07335254340251958],"y":["on  ","2020  ","2431  ","incident  ","fire  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01812521749823936,0.01913088859037139,0.02033756608999358,0.06938281279223109,0.08182707562705885],"y":["itemized  ","proposal  ","de  ","tabulations  ","group  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.011355336165049211,0.012966594046943582,0.013626171210425626,0.016284130594803246,0.024363173765843765],"y":["spill  ","oil  ","deepwater  ","donation  ","contracts  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.011506576031169,0.01243196297685556,0.01617782485444258,0.02319009306396367,0.09366845063985094],"y":["500  ","marta  ","yall  ","reports  ","incident  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ti ...
