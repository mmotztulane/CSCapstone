# %% [markdown]
# <a href="https://colab.research.google.com/github/mmotztulane/CSCapstone/blob/main/Milestone2AnalysisCharts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive

requests = pd.read_csv('Public_Records_Requests.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive

# %%
requests['Request Text']
# Out:
# 0       Any and all contracts between the city of New ...
# 1       Hello, hoping to get any records of hazardous ...
# 2       Please send me a copy of all pre and post tax ...
# 3       Please provide the following information about...
# 4       I am requesting public records of the city's e...
#                               ...
# 7733    Please provide all records related to any noti...
# 7734    H-2022-843P   Previous request # F-2022-794P C...
# 7735    A list of every graduating member of the follo...
# 7736    Please provide copies of all noting conducted ...
# 7737    I-2022-206P   Good afternoon, I need to check ...
# Name: Request Text, Length: 7738, dtype: object

# %%
requests["Responsible Department"].value_counts()
# Out:
# Fire Department (NOFD)                                                                                                 1354
# Media Request - NOPD                                                                                                    885
# Finance - Treasury                                                                                                      871
# Finance - Procurement                                                                                                   403
# Safety and Permits                                                                                                      298
#                                                                                                                        ...
# City Council; Media Request - Mayor's Office of Communications; Public Works-All                                          1
# ...

# %%
requests["Responsible Department"].value_counts().loc[requests["Responsible Department"].value_counts() >= 100].plot.pie(y='mass', figsize=(10, 10))

# %%
requests["Point of Contact"].value_counts()
# Out:
# Admin Law               3504
# Paul Degrange           1195
# Jezreel Joseph           793
# Dan Shedd                670
# Anita Curran             518
# Terry Hardy              183
# Law Admin 04             119
# David Gavlinski          106
# Law Admin NOPD           103
# Tonchelle Ward            96
# Tyler Hughes              67
# Law Admin 06              66
# Law Admin 05              59
# Tammie Jackson            43
# Rayshawn Gremillion       31
# Cynthia Jupiter           24
# Subpoena Unit             24
# Law Admin 08              23
# Dynasty Aguillard         21
# Law Admin 07              16
# Genetrice Hankton         12
# LaDon Vinnett-Powell      11
# Law Admin 09              11
# Kristen Lee                8
# Jasaun Haynes              7
# Robin Meyers               6
# Dawnella Adams             4
# Jonathan Harris            4
# Isaka Williams             3
# Veshana Gray               3
# Law Admin 03               2
# Megan Esteves              1
# ...

# %%
requests["Point of Contact"].value_counts().loc[requests["Point of Contact"].value_counts() >= 50].plot.pie(y='mass', figsize=(10, 10))
